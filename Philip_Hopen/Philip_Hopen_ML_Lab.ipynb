# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Question 1

# %%
df_ord = pd.read_csv("data/Orders.csv")
df_ord
# Out:
#        Row.ID                  Order.ID Order.Date Ship.Date       Ship.Mode  \
# 0       40098  CA-2014-AB10015140-41954   11/11/14  11/13/14     First Class
# 1       26341    IN-2014-JR162107-41675     2/5/14    2/7/14    Second Class
# 2       25330    IN-2014-CR127307-41929   10/17/14  10/18/14     First Class
# 3       13524   ES-2014-KM1637548-41667    1/28/14   1/30/14     First Class
# 4       47221   SG-2014-RH9495111-41948    11/5/14   11/6/14        Same Day
# 5       22732    IN-2014-JM156557-41818    6/28/14    7/1/14    Second Class
# 6       30570   IN-2012-TS2134092-41219    11/6/12   11/8/12     First Class
# 7       31192   IN-2013-MB1808592-41378    4/14/13   4/18/13  Standard Class
# 8       40099  CA-2014-AB10015140-41954   11/11/14  11/13/14     First Class
# 9       36258  CA-2012-AB10015140-40974     3/6/12    3/7/12     First Class
# 10      36259  CA-2012-AB10015140-40974     3/6/12    3/7/12     First Class
# ...

# %%
df_ord.columns[df_ord.isnull().any()]
# Out:
# Index(['Postal.Code'], dtype='object')

# %%
x = ['Profit', 'Sales']

df_ord[x] = df_ord[x].apply(lambda x: x.str.replace('$', ''))
df_ord[x] = df_ord[x].apply(lambda x: x.str.replace(',', ''))
df_ord[x] = df_ord[x].astype('float64')

# %%
df_ord["Postal.Code"].isnull().count()
# Out:
# 51290

# %% [markdown]
# ## Question 2

# %%
df_ord.columns
# Out:
# Index(['Row.ID', 'Order.ID', 'Order.Date', 'Ship.Date', 'Ship.Mode',
#        'Customer.ID', 'Customer.Name', 'Segment', 'Postal.Code', 'City',
#        'State', 'Country', 'Region', 'Market', 'Product.ID', 'Category',
#        'Sub.Category', 'Product.Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping.Cost', 'Order.Priority'],
#       dtype='object')

# %%
df_ord["Order.Date"] = pd.to_datetime(df_ord["Order.Date"])

df_ord["Ord.Year"] = pd.DatetimeIndex(df_ord["Order.Date"]).year
df_ord["Ord.Month"] = pd.DatetimeIndex(df_ord["Order.Date"]).month

# %%
import matplotlib.pyplot as plt
grouped_df = df_ord.groupby(["Ord.Year","Ord.Month"]).agg({"Quantity":"sum"})

grouped_df.plot(xticks=list(range(len(grouped_df)))[::3], figsize=(20,10), kind = "line")
plt.show()

# %%
#Bar graph version
grouped_df.plot(figsize=(20,10), kind = "bar")
plt.show()

# %%
df_ord["Category"].unique()
# Out:
# array(['Technology', 'Furniture', 'Office Supplies'], dtype=object)

# %%
Technology_df = df_ord.query('Category == "Technology"').groupby(["Ord.Year","Ord.Month"]).agg({"Quantity":"sum"})
Furniture_df = df_ord.query('Category == "Furniture"').groupby(["Ord.Year","Ord.Month"]).agg({"Quantity":"sum"})
Office_df = df_ord.query('Category == "Office Supplies"').groupby(["Ord.Year","Ord.Month"]).agg({"Quantity":"sum"})

# %%
import seaborn as sns

group_category = df_ord.groupby(["Category", "Ord.Year","Ord.Month"]).agg({"Quantity":"sum"})
x = group_category.reset_index()
x['MY'] = x['Ord.Month'].map(str) + '/' + x['Ord.Year'].map(str)

g = sns.FacetGrid(x, col = "Category", size = 15 )
g.map(sns.barplot, x='MY', y='Quantity', data=x)
plt.show()

# %%
Technology_df.plot(figsize=(20,10), kind = "bar")
Furniture_df.plot(figsize=(20,10), kind = "bar")
Office_df.plot(figsize=(20,10), kind = "bar")
plt.show()

# %% [markdown]
# ## Question 3

# %%
df_ret = pd.read_csv('data/Returns.csv')

# %%
df_tot = pd.merge(df_ord, df_ret, left_on = 'Order.ID', right_on = 'Order ID', how = 'left')

# %%
df_tot = df_tot.rename(index = str, columns = {'Region_x': 'Region'})

# %%
df_tot = df_tot.drop(['Order ID', 'Region_y'], axis = 1)

# %%
#3.1
df_tot[df_tot.Returned == 'Yes'].groupby('Ord.Year').agg({'Sales':'sum'})
# Out:
#               Sales
# Ord.Year
# 2012      111935.81
# 2013       96575.21
# 2014      133737.41
# 2015      183683.98

# %%
df_ord = df_ord.drop('Postal.Code', axis = 1)

# %%
#3.2
x = df_tot[df_tot.Returned == 'Yes'].groupby('Customer.ID').agg({'Sales':'count'})
print('More than 1 Return: ', len(x[x.Sales > 1]))
print('More than 5 Return: ', len(x[x.Sales > 5]))
# Out:
# More than 1 Return:  547
# More than 5 Return:  46

# %%
#3.3
df_tot[df_tot.Returned == 'Yes'].groupby('Region').agg({'Sales':'count'}).sort_values(by = 'Sales', ascending = False)
# Out:
#                    Sales
# Region
# Central America      248
# Western Europe       233
# Western US           177
# Oceania              154
# Southeastern Asia    140
# Eastern US           134
# South America        133
# Eastern Asia         131
# Southern Europe      112
# Southern Asia        111
# Western Asia         108
# Southern US           83
# Northern Europe       76
# Central US            74
# Caribbean             69
# Western Africa        60
# North Africa          51
# Eastern Europe        42
# Southern Africa       25
# Eastern Africa        18
# Central Africa        17
# Canada                15
# Central Asia           9

# %%
#3.4
df_tot[df_tot.Returned == 'Yes'].groupby('Sub.Category').agg({'Sales':'count'}).sort_values(by = 'Sales', ascending = False)
# Out:
#               Sales
# Sub.Category
# Binders         269
# Art             217
# Storage         212
# Paper           150
# Chairs          147
# Phones          145
# Accessories     138
# Labels          137
# Furnishings     135
# Bookcases       104
# Supplies        103
# Fasteners       102
# Envelopes        99
# Copiers          99
# Machines         63
# Appliances       59
# Tables           41
